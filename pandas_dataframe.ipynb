# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ##Creating DataFrame

# %% [markdown]
# ####In normal word Table but pandas called dataframe

# %%
#using lists
student_data=[
    [100,80,10],
    [90,70,7],
    [120,100,14],
    [80,50,2]
]
pd.DataFrame(student_data,columns=['iq','marks','package'])
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
#using Dicts
student_dict={
    'iq':[100,90,120,80],
    'marks':[80,70,100,50],
    'package':[10,7,14,2]
}
students = pd.DataFrame(student_dict)
students
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
#using read_csv
movies = pd.read_csv('/content/movies.csv')
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
ipl = pd.read_csv("/content/ipl-matches.csv")
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# ##DataFrame Attributes and Methods

# %%
#Shape
movies.shape
ipl.shape
# Out:
# (950, 20)

# %%
#dtypes
movies.dtypes
ipl.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
#index
movies.index
ipl.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %%
#columns
movies.columns
ipl.columns
students.columns
# Out:
# Index(['iq', 'marks', 'package'], dtype='object')

# %%
#values
students.values
ipl.values
# Out:
# array([[1312200, 'Ahmedabad', '2022-05-29', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312199, 'Ahmedabad', '2022-05-27', ...,
#         "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312198, 'Kolkata', '2022-05-25', ...,
#         "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']",
#         'J Madanagopal', 'MA Gough'],
#        ...,
#        [335984, 'Delhi', '2008-04-19', ...,
#         "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']",
# ...

# %%
#head and tail
movies.head()
movies.head(10)
ipl.tail()
ipl.tail(2)
# Out:
#          ID        City        Date   Season MatchNumber  \
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                  Team2  \
# 948              Kings XI Punjab    Chennai Super Kings
# 949  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision SuperOver            WinningTeam WonBy  Margin method  \
# 948          bat         N    Chennai Super Kings  Runs    33.0    NaN
# 949        field         N  Kolkata Knight Riders  Runs   140.0    NaN
#
#     Player_of_Match                                       Team1Players  \
# 948      MEK Hussey  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# ...

# %%
#sample
ipl.sample()
ipl.sample(5)
# Out:
#           ID       City        Date Season MatchNumber                  Team1  \
# 341  1082622    Kolkata  2017-04-28   2017          32  Kolkata Knight Riders
# 507   734019      Delhi  2014-05-19   2014          45       Delhi Daredevils
# 414   980937     Rajkot  2016-04-24   2016          19          Gujarat Lions
# 307  1136567  Hyderabad  2018-04-12   2018           7         Mumbai Indians
# 455   829781    Kolkata  2015-05-04   2015          38  Kolkata Knight Riders
#
#                            Team2                                   Venue  \
# 341             Delhi Daredevils                            Eden Gardens
# 507              Kings XI Punjab                        Feroz Shah Kotla
# 414  Royal Challengers Bangalore  Saurashtra Cricket Association Stadium
# 307          Sunrisers Hyderabad      Rajiv Gandhi International Stadium
# 455          Sunrisers Hyderabad                            Eden Gardens
#
# ...

# %%
#info   : vary vary useful when take a new dataset to understand the summay
movies.info()
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
#describe :: mainly work in mathematical term
movies.describe()
ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
#isnull  : vary vary useful when take a new dataset to find null have ro not
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
#duplicated
movies.duplicated()
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
#rename
students
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
students.rename(columns={'marks':'percent','package':'lpa'}) #temporary change
# Out:
#     iq  percent  lpa
# 0  100       80   10
# 1   90       70    7
# 2  120      100   14
# 3   80       50    2

# %%
students.rename(columns={'marks':'percent','package':'lpa'},inplace=True) #permanent change

# %% [markdown]
# ##Math Methods

# %%
#sum -> axis arguments
students.sum()   #column added
students.sum(axis=1)   #row added
# Out:
# 0    190
# 1    167
# 2    234
# 3    132
# dtype: int64

# %%
#mean
students.mean()   #column added
students.mean(axis=1)   #row added
students.mean(axis=0)   #column added
# Out:
# iq         97.50
# marks      75.00
# package     8.25
# dtype: float64

# %%
#max/min/median/std/var

# %% [markdown]
# #Selecting cols from a DataFrame

# %%
#single cols
movies['actors']
#type(movies['actors'])
# Out:
# 0       Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1       Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2       Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# 3       Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...
# 4       Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...
#                               ...
# 1624    Ajay Devgn|Sonali Bendre|Namrata Shirodkar|Pre...
# 1625    Ameesha Patel|Jimmy Sheirgill|Nafisa Ali|Gulsh...
# 1626    Vijay Arora|Asrani|Rajni Bala|Kumud Damle|Utpa...
# 1627                            Gippy Grewal|Zareen Khan|
# 1628                                          Fawad Khan|
# Name: actors, Length: 1629, dtype: object

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
ipl['Venue']
# Out:
# 0                Narendra Modi Stadium, Ahmedabad
# 1                Narendra Modi Stadium, Ahmedabad
# 2                           Eden Gardens, Kolkata
# 3                           Eden Gardens, Kolkata
# 4                        Wankhede Stadium, Mumbai
#                           ...
# 945                                  Eden Gardens
# 946                              Wankhede Stadium
# 947                              Feroz Shah Kotla
# 948    Punjab Cricket Association Stadium, Mohali
# 949                         M Chinnaswamy Stadium
# Name: Venue, Length: 950, dtype: object

# %%
#multiple cols
movies[['title_x','year_of_release','actors']]
# Out:
#                                    title_x  year_of_release  \
# 0                 Uri: The Surgical Strike             2019
# 1                            Battalion 609             2019
# 2     The Accidental Prime Minister (film)             2019
# 3                          Why Cheat India             2019
# 4                          Evening Shadows             2018
# ...                                    ...              ...
# 1624                 Tera Mera Saath Rahen             2001
# 1625                  Yeh Zindagi Ka Safar             2001
# 1626                       Sabse Bada Sukh             2018
# 1627                                 Daaka             2019
# 1628                              Humsafar             2011
#
#                                                  actors
# 0     Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1     Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2     Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# ...

# %%
type(movies[['title_x','year_of_release','actors']])
# Out:
# pandas.core.frame.DataFrame

# %%
ipl[['Team1','Team2','WinningTeam']]
# Out:
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                      WinningTeam
# 0                 Gujarat Titans
# 1               Rajasthan Royals
# 2    Royal Challengers Bangalore
# 3                 Gujarat Titans
# 4                   Punjab Kings
# ...

# %%
student_dicts={
    'name':['Hridoy','Prince','Mukta','Sagor','Uttam','Laboni'],
    'iq':[100,90,120,80,50,24],
    'marks':[80,70,100,50,60,34],
    'package':[10,7,14,2,1,.5]
}
student = pd.DataFrame(student_dicts)
student.set_index('name',inplace=True)
student
# Out:
#          iq  marks  package
# name
# Hridoy  100     80     10.0
# Prince   90     70      7.0
# Mukta   120    100     14.0
# Sagor    80     50      2.0
# Uttam    50     60      1.0
# Laboni   24     34      0.5

# %% [markdown]
# ##Selecting rows from a DataFrame

# %% [markdown]
# <p>. iloc-searches using index positions</p>
# <p>. loc-searches using index labels</p>

# %%
#single row
movies.iloc[0]
# Out:
# title_x                                      Uri: The Surgical Strike
# imdb_id                                                     tt8291224
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link           https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# title_y                                      Uri: The Surgical Strike
# original_title                               Uri: The Surgical Strike
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           138
# genres                                               Action|Drama|War
# imdb_rating                                                       8.4
# imdb_votes                                                      35112
# story               Divided over five chapters  the film chronicle...
# ...

# %%
type(movies.iloc[0])
# Out:
# pandas.core.series.Series

# %%
#multiple rows
movies.iloc[0:5]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
type(movies.iloc[0:5])
# Out:
# pandas.core.frame.DataFrame

# %%
movies.iloc[5:55:3]
# Out:
#                                  title_x    imdb_id  \
# 5                            Soni (film)  tt6078866
# 8       Manikarnika: The Queen of Jhansi  tt6903440
# 11                             Gully Boy  tt2395469
# 14                            Sonchiriya  tt8108200
# 17                          Hamid (film)  tt7527082
# 20             Mere Pyare Prime Minister  tt8207768
# 23                  Notebook (2019 film)  tt9105014
# 26  Albert Pinto Ko Gussa Kyun Aata Hai?  tt4355838
# 29                        Setters (film)  tt9239772
# 32                        De De Pyaar De  tt8647400
# 35                  Khamoshi (2019 film)  tt8268972
# 38            One Day: Justice Delivered  tt8130558
# 41                  Family of Thakurganj  tt8897986
# 44                  Judgementall Hai Kya  tt8108196
# 47                         Jabariya Jodi  tt8785426
# 50                        Mission Mangal  tt9248972
# 53                           Section 375  tt8144834
#
# ...

# %%
#Fancy indexing
movies.iloc[[0,5,7,2]]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 5                           Soni (film)  tt6078866
# 7                            Bombairiya  tt4971258
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
# 7  https://upload.wikimedia.org/wikipedia/en/thum...
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 5          https://en.wikipedia.org/wiki/Soni_(film)
# 7           https://en.wikipedia.org/wiki/Bombairiya
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# ...

# %%
#loc(location)
student
# Out:
#          iq  marks  package
# name
# Hridoy  100     80     10.0
# Prince   90     70      7.0
# Mukta   120    100     14.0
# Sagor    80     50      2.0
# Uttam    50     60      1.0
# Laboni   24     34      0.5

# %%
student.loc['Hridoy']
# Out:
# iq         100.0
# marks       80.0
# package     10.0
# Name: Hridoy, dtype: float64

# %%
student.loc['Hridoy':'Mukta']
# Out:
#          iq  marks  package
# name
# Hridoy  100     80     10.0
# Prince   90     70      7.0
# Mukta   120    100     14.0

# %% [markdown]
# ####Main difference iloc and loc is loc include the last row that is given and iloc not included..

# %%
student.loc['Hridoy':'Mukta':2]
# Out:
#          iq  marks  package
# name
# Hridoy  100     80     10.0
# Mukta   120    100     14.0

# %% [markdown]
# ##Selecting both rows and cols

# %%
movies.iloc[0:3,0:3]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
movies.loc[0:5,'title_x':'original_title']
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
# 5                           Soni (film)  tt6078866
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# ...

# %%
movies.loc[0:5,['title_x','actors']]
# Out:
#                                 title_x  \
# 0              Uri: The Surgical Strike
# 1                         Battalion 609
# 2  The Accidental Prime Minister (film)
# 3                       Why Cheat India
# 4                       Evening Shadows
# 5                           Soni (film)
#
#                                               actors
# 0  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1  Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2  Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# 3  Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...
# 4  Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...
# 5  Geetika Vidya Ohlyan|Saloni Batra|Vikas Shukla...

# %% [markdown]
# ##Filtering a DataFrame
# <p>Going forward this topic is used more more </p>

# %%
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
#Find all  the final winners
new_df = ipl[ipl['MatchNumber'] == 'Final']
new_df[['Season','Team1','Team2','WinningTeam']]
# Out:
#       Season                        Team1                        Team2  \
# 0       2022             Rajasthan Royals               Gujarat Titans
# 74      2021          Chennai Super Kings        Kolkata Knight Riders
# 134  2020/21               Delhi Capitals               Mumbai Indians
# 194     2019               Mumbai Indians          Chennai Super Kings
# 254     2018          Sunrisers Hyderabad          Chennai Super Kings
# 314     2017               Mumbai Indians       Rising Pune Supergiant
# 373     2016  Royal Challengers Bangalore          Sunrisers Hyderabad
# 433     2015               Mumbai Indians          Chennai Super Kings
# 492     2014        Kolkata Knight Riders              Kings XI Punjab
# 552     2013          Chennai Super Kings               Mumbai Indians
# 628     2012        Kolkata Knight Riders          Chennai Super Kings
# 702     2011          Chennai Super Kings  Royal Challengers Bangalore
# ...

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
#how many super over finishes have occured
ipl[ipl['SuperOver'] == 'Y'][['Season','Team1','Team2','WinningTeam']]
ipl[ipl['SuperOver'] == 'Y'].shape[0]
# Out:
# 14

# %%
#how many matches has csk won in Kolkata (Sir solution)
winByCSK = ipl[(ipl['WinningTeam'] == 'Chennai Super Kings') &(ipl['City'] == 'Kolkata')].shape[0]
winByCSK
# Out:
# 5

# %%
#My solution
winByCSK = ipl[ipl['WinningTeam'] == 'Chennai Super Kings']
winByCSK[winByCSK['City'] == 'Kolkata'][['City','Season','Team1','Team2','WinningTeam']]
# Out:
#         City   Season                  Team1                Team2  \
# 224  Kolkata     2019  Kolkata Knight Riders  Chennai Super Kings
# 602  Kolkata     2013  Kolkata Knight Riders  Chennai Super Kings
# 641  Kolkata     2012  Kolkata Knight Riders  Chennai Super Kings
# 827  Kolkata  2009/10  Kolkata Knight Riders  Chennai Super Kings
# 908  Kolkata  2007/08  Kolkata Knight Riders  Chennai Super Kings
#
#              WinningTeam
# 224  Chennai Super Kings
# 602  Chennai Super Kings
# 641  Chennai Super Kings
# 827  Chennai Super Kings
# 908  Chennai Super Kings

# %%
#toss winner is match winner in percentage
(ipl[ipl['TossWinner'] == ipl['WinningTeam']].shape[0]/ipl.shape[0])*100
# Out:
# 51.473684210526315

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#movies with rating higher than 8 and votes>10000
movies[(movies['imdb_rating'] > 8) & (movies['imdb_votes'] > 10000)].shape[0]
# Out:
# 43

# %%
#Action movies with rating higher than 7.5  :Tricky question
movies[(movies['genres'].str.split('|').apply(lambda x: 'Action' in x)) & (movies['imdb_rating'] > 7.5)]
# Out:
#                             title_x    imdb_id  \
# 0          Uri: The Surgical Strike  tt8291224
# 41             Family of Thakurganj  tt8897986
# 84                        Mukkabaaz  tt7180544
# 106                           Raazi  tt7098658
# 110   Parmanu: The Story of Pokhran  tt6826438
# 112         Bhavesh Joshi Superhero  tt6129302
# 169                The Ghazi Attack  tt6299040
# 219                Raag Desh (film)  tt6080746
# 258                   Irudhi Suttru  tt5310090
# 280                       Laal Rang  tt5600714
# 297                     Udta Punjab  tt4434004
# 354                   Dangal (film)  tt5074352
# 362               Bajrangi Bhaijaan  tt3863552
# 365          Baby (2015 Hindi film)  tt3848892
# 393      Detective Byomkesh Bakshy!  tt3447364
# 449               Titli (2014 film)  tt3019620
# 536                   Haider (film)  tt3390572
# 589                    Vishwaroopam  tt2199711
# 625                     Madras Cafe  tt2855648
# ...

# %%
movies[(movies['genres'].str.contains('Action')) & (movies['imdb_rating'] > 7.5)]
# Out:
#                             title_x    imdb_id  \
# 0          Uri: The Surgical Strike  tt8291224
# 41             Family of Thakurganj  tt8897986
# 84                        Mukkabaaz  tt7180544
# 106                           Raazi  tt7098658
# 110   Parmanu: The Story of Pokhran  tt6826438
# 112         Bhavesh Joshi Superhero  tt6129302
# 169                The Ghazi Attack  tt6299040
# 219                Raag Desh (film)  tt6080746
# 258                   Irudhi Suttru  tt5310090
# 280                       Laal Rang  tt5600714
# 297                     Udta Punjab  tt4434004
# 354                   Dangal (film)  tt5074352
# 362               Bajrangi Bhaijaan  tt3863552
# 365          Baby (2015 Hindi film)  tt3848892
# 393      Detective Byomkesh Bakshy!  tt3447364
# 449               Titli (2014 film)  tt3019620
# 536                   Haider (film)  tt3390572
# 589                    Vishwaroopam  tt2199711
# 625                     Madras Cafe  tt2855648
# ...

# %%
#Write a function that can return the track recode of 2 teams against each other

# %%
movies.sample(4)
# Out:
#                       title_x    imdb_id  \
# 1159             Dil Diya Hai  tt0814082
# 844   Jaane Kahan Se Aayi Hai  tt1194232
# 1601         Maya (2001 film)  tt0299027
# 1580            Censor (film)  tt0272543
#
#                                             poster_path  \
# 1159  https://upload.wikimedia.org/wikipedia/en/thum...
# 844   https://upload.wikimedia.org/wikipedia/en/thum...
# 1601  https://upload.wikimedia.org/wikipedia/en/thum...
# 1580  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 1159         https://en.wikipedia.org/wiki/Dil_Diya_Hai
# 844   https://en.wikipedia.org/wiki/Jaane_Kahan_Se_A...
# 1601     https://en.wikipedia.org/wiki/Maya_(2001_film)
# 1580        https://en.wikipedia.org/wiki/Censor_(film)
#
#                       title_y           original_title  is_adult  \
# 1159             Dil Diya Hai             Dil Diya Hai         0
# ...

# %% [markdown]
# ##Adding new cols

# %%
#Completely new
movies['Country'] ='India'
movies.head(4)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# ...

# %%
movies.sample(4)
# Out:
#                         title_x    imdb_id  \
# 375                 Khamoshiyan  tt3886444
# 210               Munna Michael  tt6117702
# 1275  Mangal Pandey: The Rising  tt0346457
# 615                      Enemmy  tt2941856
#
#                                             poster_path  \
# 375   https://upload.wikimedia.org/wikipedia/en/thum...
# 210   https://upload.wikimedia.org/wikipedia/en/thum...
# 1275  https://upload.wikimedia.org/wikipedia/en/thum...
# 615   https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 375           https://en.wikipedia.org/wiki/Khamoshiyan
# 210         https://en.wikipedia.org/wiki/Munna_Michael
# 1275  https://en.wikipedia.org/wiki/Mangal_Pandey:_T...
# 615                https://en.wikipedia.org/wiki/Enemmy
#
#                         title_y             original_title  is_adult  \
# 375                 Khamoshiyan                Khamoshiyan         0
# ...

# %%
#Remove missing value
#movies.dropna(inplace=True)  # remove all rows where exist missing value

# %%
#from existing ones
movies['lead actors'] = movies['actors'].str.split('').apply(lambda x:x[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-140-42a49e0a8e38> in <cell line: 0>()
#       1 #from existing ones
# ----> 2 movies['actors'].str.split(',').apply(lambda x:x[0])
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1505         #  Categorical (GH51645).
# ...

# %% [markdown]
# ##Important DataFrame Functions

# %%
#astype
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl['ID'] = ipl['ID'].astype('int32')
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
#ipl['Season']=ipl['Season'].astype('category')
ipl['Team1']=ipl['Team1'].astype('category')
ipl['Team2']=ipl['Team2'].astype('category')
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    category
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    category
#  6   Team2            950 non-null    category
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
#value_counts

# %%
#find which player has won most potm -> in finals and qualifiers

# %%
#Toss decision plot

# %%
#how many matches each team has played

# %%
#sort_values -> ascending -> na_position - inplace -> multiple cols
